# %% [markdown]
# # B1. What is python, name some of features of python
# Ans- Python is a dynamic, high level, free open source and interpreted programming language. It supports object-oriented programming as well as procedural oriented programming.
# In Python, we don’t need to declare the type of variable because it is a dynamically typed language.
# ##Features-
# 1. Easy to code.
# 2. Free and open source.
# 3. GUI programming support.
# 4. High level language.
# 5. Dynamically typed language.

# %%
#B2 Python version

# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# #B3
# Ans- Yes,Python is incredibly easy to read, so developers typically have no problems understanding code written by their fellow programmers.

# %% [markdown]
# #B4
# Ans- When he began implementing Python, Guido van Rossum was also reading the published scripts from “Monty Python's Flying Circus”, a BBC comedy series from the 1970s. Van Rossum thought he needed a name that was short, unique, and slightly mysterious, so he decided to call the language Python.

# %% [markdown]
# #B5

# %%
a = input('Enter any number:  ')
a = int(a)
if a > 0:
   print("Positive number")
if a == 0:
   print("Zero")

if a < 0:
   print("Negative number")
# Out:
# Enter any number:  1
# Positive number

# %% [markdown]
# #B6
# Ans- Python is derived from many other languages, including ABC, Modula-3, C, C++, Algol-68, SmallTalk, and Unix shell and other scripting languages

# %%
#B7
data = input("Enter number and string   ")

if data.isnumeric():
  print('Its a number')
  
  
else:
  print('Its a string')
# Out:
# Enter number and string   www
# its string

# %% [markdown]
# #B8
# Ans- NO, Python does not support switch or case statement.

# %% [markdown]
# #B9
# Ans-
#
#  Python program runs directly from the source code.
#
# - Each time Python programs are executed code is required.
#
# - Python converts source code written by the programmer into intermediate language which is again translated into the native language / machine language that is executed. So Python is an Interpreted language.

# %%
#B 10
num = int(input('Enter any number  '))
fact = 1

if (num <= 0):
  print('Invalid') 

else:
    for i in range(1 , num+1 ):
       fact = fact*i

print("Factorial of " f'{num}' " is " f'{fact}')
# Out:
# Enter any number  3
# Factorial of 3 is 6

# %% [markdown]
# #B12
# Ans - The Python memory manager manages chunks of memory called “Blocks”. A collection of blocks of the same size makes up the “Pool”. Pools are created on Arenas, chunks of 256kB memory allocated on heap=64 pools. If the objects get destroyed, the memory manager fills this space with a new object of the same size.

# %% [markdown]
# #B13
# Ans- A namespace is a system that has a unique name for each and every object in Python. An object might be a variable or a method. Python itself maintains a namespace in the form of a Python dictionary.

# %% [markdown]
# #B14
# Ans - The continue statement gives you the option to skip over the part of a loop where an external condition is triggered, but to go on to complete the rest of the loop. That is, the current iteration of the loop will be disrupted, but the program will return to the top of the loop.

# %%
#I1
#With Temp variable

x = input('Enter value of x  ')
y = input('Enter valie of y  ')

temp = x
x = y
y = temp

print('Value of x  '  f'{x}')
print('Value of y  '  f'{y}')
# Out:
# Enter value of x  1
# Enter valie of y  2
# Value of x  2
# Value of y  1

# %%
#Without temp

x = 1
y = 2

x , y = y ,x
print(x)
print(y)
# Out:
# 2
# 1

# %%
#I2 
a = input('Enter any number   ')
if a.isnumeric():
 a = int (a)

 if a % 2 == 0:
   print(f'{a} is even number')


 else:
     print(f'{a} is an odd number')
# Out:
# Enter any number   3
# 3 is an odd number

# %%
#I3, 1
a = int(input('Enter base of the triangle   '))
b = int(input('Enter height of the triangle  '))

area = (a*b)/2

print('Area of triangle is  ' f'{area}')
# Out:
# Enter base of the triangle   3
# Enter height of the triangle  4
# Area of triangle is  6.0

# %%
#I3,2
a = float(input('Enter radius of the circle   '))

area = 3.14*a*a

print('Area of circle is  ' f'{area}')
# Out:
# Enter radius of the circle   1
# Area of circle is  3.14

# %%
#I4
a = input('Enter any alphabet    ')

if (a == 'a') or (a == 'e') or (a == 'u') or (a == 'i') or (a == 'o'):
  print(f'{a} is vowel')
else:
  print(f'{a} is consonant')
# Out:
# Enter any alphabet    a
# a is vowel

# %%
#I5
P = int(input('Enter principle amount - '))
R = int(input('Enter rate of interest in % - '))
Y = int(input('Enter time in years - '))


i = (P*R*Y)/100

print("simple interest is   " f'{i}')
# Out:
# Enter principle amount - 100
# Enter rate of interest in % - 2
# Enter time in years - 2
# simple interest is   4.0

# %%
#A1
l =[2,3,4,5,9,8,10,22,11]
l.sort()

# %%
l
# Out:
# [2, 3, 4, 5, 8, 9, 10, 11, 22]

# %%
#A2
a = int(input('Enter any number'))

b = a+a*a+a*a*a

print(b)
# Out:
# Enter any number2
# 14

# %%
a = int(input('Enter any number'))

b = a
c = 10*a + b
d = 100*a+ c

e = b + c +d

print(e)
# Out:
# Enter any number5
# 615

# %%
#A3
a = int(input('Enter 1st number   '))
b = int(input('Enter 2nd number   '))
c = int(input('Enter 3rd number   '))


d = a + b+ c
if ( a==b or b==c or c==a):
  print('sum is zero')
  
  
else:
  
  
     print('sum is   ' f'{d}')
# Out:
# Enter 1st number   2
# Enter 2nd number   2
# Enter 3rd number   1
# sum is zero

# %%
#A4
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd Number: "))
if(a==b or a-b==5 or a+b==5):
  print("True")

else:
  print("False")
# Out:
# Enter 1st number: 4
# Enter 2nd Number: 6
# false

# %%
#A5
a = int(input('Enter any number   '))
 
s = a*(a+1)/2

print(s)
# Out:
# Enter any number   10
# 55.0

# %%
# String Operations
#B1
d = "Hello world"
len(d)
# Out:
# 11

# %%
#B2
d = 'welcome to world'
d.count('o')
# Out:
# 3

# %% [markdown]
# #B3
# Ans -  Negative index means that the index value of -1 gives the last element, and -2 gives the second last element.
#
# ###Use
#  A negative index accesses elements from the end of the list counting backward.

# %%
# B6
d = 'welcome to world'
d.count('w')
# Out:
# 2

# %%
#B7
d = "Hello world"
a = ''

for i in d:
  if i not in a:
    a += i
   
for i in a:
   print(f'{i} is {d.count(i)} times')
# Out:
# H is 1 times
# e is 1 times
# l is 3 times
# o is 2 times
#   is 1 times
# w is 1 times
# r is 1 times
# d is 1 times

# %%
#I1
a = 'Hello students   '
b = 'Welcome to the class'

c = a+b
print(c)

x =  slice(0,2)
y = slice(0,2)

temp = x
y = x
x = temp

c = a.replace('he','we')
d = b.replace('we','he')

print(c)
print(d)
# Out:
# Hello students   Welcome to the class
# Hello students
# Welcome to the class

# %%
#I2
a = str(input('Enter any word   '))
l = len(a)

if (len(a) < 3 ):
   print(a)
  
if (len(a)>=3):
  print(a)

if a.endswith('ing'):
     a = a[0:l-3]
print(a +'ly')

if (a[-1] != 'g'):
  print(a + 'ing')
# Out:
# Enter any word   as
# as
# asly
# asing

# %%
a = str(input('Enter any word   '))
l = len(a)

if (len(a) < 3 ):
   print(a)
  
if (len(a)>=3):
  print(a)

if a.endswith('ing'):
     a = a[0:l-3]
print(a +'ly')

if (a[-1] != 'g'):
  print(a + 'ing')

# %%
#A3
def string(a,d):
  e=int(len(a)/2)
  return a[:e]+d+a[e: ]

# %%
string('hello','world')
# Out:
# 'heworldllo'

# %%
a = str(input('Enter any string '))
b = len(a)
c = int(b/2)
d = str(input('String to be inserted in between  '))

e = a[:c] + d +a[c:]

print(e)

# %%
#I4
a = str(input('Enter any word  '))
b = str(input('Enter any word  '))
c = str(input('Enter any word  '))

d = len(a)
e = len(b)
f = len(c)

g = max(d,e,f)

if g == d:
  print(a)

  if g == e:
    print(b)

    if g == f:
      print(c)
# Out:
# Enter any wordeee
# Enter any wordwww
# Enter any wordq
# eee
# www

# %%
def maximum(a,b,c):
  return (max(a,b,c))

# %%
maximum('hello','to','everyone')
# Out:
# 'to'
